# %%
import numpy as np
import pandas as pd
from sklearn import svm, model_selection, preprocessing, pipeline, impute, feature_selection
from sklearn.experimental import enable_iterative_imputer
from itertools import chain, combinations, product
import math
import time

import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=UserWarning)


import pyAgrum as gum
import pyAgrum.lib.notebook as gnb

# %matplotlib inline
from pyAgrum.lib.bn2roc import showROC
from pyAgrum.lib.bn2roc import showPR
from pyAgrum.lib.bn2roc import showROC_PR

import networkx as nx
import graphviz

# %%
data = pd.read_csv("insurance.csv")
data
# Out:
#        GoodStudent         Age    SocioEcon RiskAversion VehicleYear  \
# 0            False       Adult        Prole  Adventurous       Older
# 1            False      Senior        Prole     Cautious     Current
# 2            False      Senior  UpperMiddle   Psychopath     Current
# 3            False  Adolescent       Middle       Normal       Older
# 4            False  Adolescent        Prole       Normal       Older
# ...            ...         ...          ...          ...         ...
# 19995        False       Adult        Prole  Adventurous       Older
# 19996        False       Adult       Middle       Normal       Older
# 19997        False      Senior  UpperMiddle       Normal     Current
# 19998        False       Adult       Middle       Normal       Older
# 19999        False       Adult       Middle       Normal       Older
#
#       ThisCarDam RuggedAuto  Accident    MakeModel DrivQuality  ... HomeBase  \
# 0       Moderate   EggShell      Mild      Economy        Poor  ...     City
# 1           None   Football      None      Economy      Normal  ...     City
# 2           None   Football      None  FamilySedan   Excellent  ...     City
# 3           None   EggShell      None      Economy      Normal  ...   Suburb
# 4       Moderate   Football  Moderate      Economy        Poor  ...     City
# ...          ...        ...       ...          ...         ...  ...      ...
# 19995       Mild   Football      Mild      Economy        Poor  ...     City
# 19996       None       Tank      None  FamilySedan      Normal  ...   Suburb
# 19997       None   Football      None       Luxury   Excellent  ...   Secure
# 19998       None   Football      None  FamilySedan   Excellent  ...   Suburb
# 19999       None       Tank      None  FamilySedan   Excellent  ...   Secure
#
#        AntiTheft  PropCost  OtherCarCost OtherCar   MedCost Cushioning Airbag  \
# 0          False   TenThou      Thousand     True  Thousand       Poor  False
# 1           True  Thousand      Thousand     True  Thousand       Good   True
# 2          False  Thousand      Thousand    False  Thousand       Good   True
# 3          False  Thousand      Thousand     True  Thousand       Fair  False
# 4          False   TenThou      Thousand    False  Thousand       Fair  False
# ...          ...       ...           ...      ...       ...        ...    ...
# 19995      False  Thousand      Thousand     True  Thousand       Fair  False
# 19996      False  Thousand      Thousand     True  Thousand       Good  False
# 19997       True   TenThou      Thousand    False  Thousand  Excellent   True
# 19998      False  Thousand      Thousand     True  Thousand       Good   True
# 19999      False  Thousand      Thousand     True  Thousand  Excellent   True
#
#         ILiCost DrivHist
# 0      Thousand     Many
# 1      Thousand     Zero
# 2      Thousand      One
# 3      Thousand     Zero
# 4      Thousand     Many
# ...         ...      ...
# 19995  Thousand     Many
# 19996  Thousand     Zero
# 19997  Thousand     Zero
# 19998  Thousand     Zero
# 19999  Thousand     Zero
#
# [20000 rows x 27 columns]

# %%
#X = data[data.columns.drop(["RiskAversion", "Accident"])]
#y = data[["RiskAversion", "Accident"]]

X = data[data.columns.drop("Accident")]
y = data["Accident"]

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y)

# %%
app = X_train.copy()
app["Accident"] = y_train

learner=gum.BNLearner(app)

bn = learner.learnBN()

bn=learner.useGreedyHillClimbing().useScoreK2().learnBN()

# %%
gnb.flow.add(gnb.getBN(bn,size="20"))
gnb.flow.display()
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 2px solid #FFFFFF;
#       valign:middle;
#       background-color: #FDFDFD;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="952pt" height="764pt" viewBox="0.00 0.00 951.54 764.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 760)">
# <title>G</title>
# <!-- DrivingSkill -->
# <g id="node1" class="node">
# <title>DrivingSkill</title>
# <g id="a_node1"><a xlink:title="(11) DrivingSkill">
# <ellipse fill="#404040" stroke="black" cx="86.95" cy="-522" rx="65.79" ry="18"/>
# <text text-anchor="middle" x="86.95" y="-518.3" font-family="Times,serif" font-size="14.00" fill="white">DrivingSkill</text>
# </a>
# </g>
# </g>
# <!-- DrivQuality -->
# <g id="node14" class="node">
# <title>DrivQuality</title>
# <g id="a_node14"><a xlink:title="(8) DrivQuality">
# <ellipse fill="#404040" stroke="black" cx="253.95" cy="-306" rx="64.19" ry="18"/>
# <text text-anchor="middle" x="253.95" y="-302.3" font-family="Times,serif" font-size="14.00" fill="white">DrivQuality</text>
# </a>
# </g>
# </g>
# <!-- DrivingSkill&#45;&gt;DrivQuality -->
# <g id="edge14" class="edge">
# <title>DrivingSkill-&gt;DrivQuality</title>
# <g id="a_edge14"><a xlink:title="(11, 8) : ">
# <path fill="none" stroke="#4a4a4a" d="M68.27,-504.49C35.58,-473.62 -25.17,-406.12 11.95,-360 33.13,-333.68 119.44,-319.7 182.98,-312.83"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="183.38,-316.31 192.97,-311.79 182.66,-309.35 183.38,-316.31"/>
# </a>
# </g>
# </g>
# <!-- DrivHist -->
# <g id="node27" class="node">
# <title>DrivHist</title>
# <g id="a_node27"><a xlink:title="(25) DrivHist">
# <ellipse fill="#404040" stroke="black" cx="70.95" cy="-378" rx="50.09" ry="18"/>
# <text text-anchor="middle" x="70.95" y="-374.3" font-family="Times,serif" font-size="14.00" fill="white">DrivHist</text>
# </a>
# </g>
# </g>
# <!-- DrivingSkill&#45;&gt;DrivHist -->
# <g id="edge35" class="edge">
# <title>DrivingSkill-&gt;DrivHist</title>
# <g id="a_edge35"><a xlink:title="(11, 25) : ">
# <path fill="none" stroke="#4a4a4a" d="M85.02,-503.87C82.29,-479.67 77.28,-435.21 74.04,-406.39"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="77.48,-405.73 72.89,-396.19 70.53,-406.52 77.48,-405.73"/>
# </a>
# </g>
# </g>
# <!-- MedCost -->
# <g id="node2" class="node">
# <title>MedCost</title>
# <g id="a_node2"><a xlink:title="(21) MedCost">
# <ellipse fill="#404040" stroke="black" cx="768.95" cy="-162" rx="51.99" ry="18"/>
# <text text-anchor="middle" x="768.95" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">MedCost</text>
# </a>
# </g>
# </g>
# <!-- Airbag -->
# <g id="node3" class="node">
# <title>Airbag</title>
# <g id="a_node3"><a xlink:title="(23) Airbag">
# <ellipse fill="#404040" stroke="black" cx="901.95" cy="-306" rx="41.69" ry="18"/>
# <text text-anchor="middle" x="901.95" y="-302.3" font-family="Times,serif" font-size="14.00" fill="white">Airbag</text>
# </a>
# </g>
# </g>
# <!-- Cushioning -->
# <g id="node5" class="node">
# <title>Cushioning</title>
# <g id="a_node5"><a xlink:title="(22) Cushioning">
# <ellipse fill="#404040" stroke="black" cx="774.95" cy="-234" rx="63.09" ry="18"/>
# <text text-anchor="middle" x="774.95" y="-230.3" font-family="Times,serif" font-size="14.00" fill="white">Cushioning</text>
# </a>
# </g>
# </g>
# <!-- Airbag&#45;&gt;Cushioning -->
# <g id="edge9" class="edge">
# <title>Airbag-&gt;Cushioning</title>
# <g id="a_edge9"><a xlink:title="(23, 22) : ">
# <path fill="none" stroke="#4a4a4a" d="M877.16,-291.34C858.55,-281.08 832.76,-266.86 811.74,-255.28"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="813.21,-252.09 802.77,-250.33 809.83,-258.22 813.21,-252.09"/>
# </a>
# </g>
# </g>
# <!-- GoodStudent -->
# <g id="node4" class="node">
# <title>GoodStudent</title>
# <g id="a_node4"><a xlink:title="(0) GoodStudent">
# <ellipse fill="#404040" stroke="black" cx="787.95" cy="-450" rx="71.49" ry="18"/>
# <text text-anchor="middle" x="787.95" y="-446.3" font-family="Times,serif" font-size="14.00" fill="white">GoodStudent</text>
# </a>
# </g>
# </g>
# <!-- Cushioning&#45;&gt;MedCost -->
# <g id="edge44" class="edge">
# <title>Cushioning-&gt;MedCost</title>
# <g id="a_edge44"><a xlink:title="(22, 21) : ">
# <path fill="none" stroke="#4a4a4a" d="M773.47,-215.7C772.8,-207.98 772.01,-198.71 771.27,-190.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="774.76,-189.77 770.41,-180.1 767.78,-190.37 774.76,-189.77"/>
# </a>
# </g>
# </g>
# <!-- Theft -->
# <g id="node6" class="node">
# <title>Theft</title>
# <g id="a_node6"><a xlink:title="(14) Theft">
# <ellipse fill="#404040" stroke="black" cx="349.95" cy="-234" rx="35.19" ry="18"/>
# <text text-anchor="middle" x="349.95" y="-230.3" font-family="Times,serif" font-size="14.00" fill="white">Theft</text>
# </a>
# </g>
# </g>
# <!-- ThisCarCost -->
# <g id="node12" class="node">
# <title>ThisCarCost</title>
# <g id="a_node12"><a xlink:title="(13) ThisCarCost">
# <ellipse fill="#404040" stroke="black" cx="450.95" cy="-162" rx="67.69" ry="18"/>
# <text text-anchor="middle" x="450.95" y="-158.3" font-family="Times,serif" font-size="14.00" fill="white">ThisCarCost</text>
# </a>
# </g>
# </g>
# <!-- Theft&#45;&gt;ThisCarCost -->
# <g id="edge8" class="edge">
# <title>Theft-&gt;ThisCarCost</title>
# <g id="a_edge8"><a xlink:title="(14, 13) : ">
# <path fill="none" stroke="#4a4a4a" d="M369.9,-219.17C383.97,-209.42 403.1,-196.16 419.24,-184.97"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="421.63,-187.58 427.85,-179.01 417.64,-181.83 421.63,-187.58"/>
# </a>
# </g>
# </g>
# <!-- RiskAversion -->
# <g id="node7" class="node">
# <title>RiskAversion</title>
# <g id="a_node7"><a xlink:title="(3) RiskAversion">
# <ellipse fill="#404040" stroke="black" cx="187.95" cy="-450" rx="71.49" ry="18"/>
# <text text-anchor="middle" x="187.95" y="-446.3" font-family="Times,serif" font-size="14.00" fill="white">RiskAversion</text>
# </a>
# </g>
# </g>
# <!-- RiskAversion&#45;&gt;DrivQuality -->
# <g id="edge43" class="edge">
# <title>RiskAversion-&gt;DrivQuality</title>
# <g id="a_edge43"><a xlink:title="(3, 8) : ">
# <path fill="none" stroke="#4a4a4a" d="M177.33,-431.91C167.2,-413.19 155.21,-382.81 167.95,-360 176.37,-344.91 191.06,-333.58 205.93,-325.36"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="207.86,-328.31 215.16,-320.63 204.67,-322.08 207.86,-328.31"/>
# </a>
# </g>
# </g>
# <!-- AntiTheft -->
# <g id="node16" class="node">
# <title>AntiTheft</title>
# <g id="a_node16"><a xlink:title="(17) AntiTheft">
# <ellipse fill="#404040" stroke="black" cx="230.95" cy="-378" rx="53.89" ry="18"/>
# <text text-anchor="middle" x="230.95" y="-374.3" font-family="Times,serif" font-size="14.00" fill="white">AntiTheft</text>
# </a>
# </g>
# </g>
# <!-- RiskAversion&#45;&gt;AntiTheft -->
# <g id="edge45" class="edge">
# <title>RiskAversion-&gt;AntiTheft</title>
# <g id="a_edge45"><a xlink:title="(3, 17) : ">
# <path fill="none" stroke="#4a4a4a" d="M198.36,-432.05C203.43,-423.8 209.63,-413.7 215.26,-404.54"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="218.38,-406.14 220.64,-395.79 212.42,-402.48 218.38,-406.14"/>
# </a>
# </g>
# </g>
# <!-- HomeBase -->
# <g id="node26" class="node">
# <title>HomeBase</title>
# <g id="a_node26"><a xlink:title="(16) HomeBase">
# <ellipse fill="#404040" stroke="black" cx="362.95" cy="-378" rx="60.39" ry="18"/>
# <text text-anchor="middle" x="362.95" y="-374.3" font-family="Times,serif" font-size="14.00" fill="white">HomeBase</text>
# </a>
# </g>
# </g>
# <!-- RiskAversion&#45;&gt;HomeBase -->
# <g id="edge6" class="edge">
# <title>RiskAversion-&gt;HomeBase</title>
# <g id="a_edge6"><a xlink:title="(3, 16) : ">
# <path fill="none" stroke="#4a4a4a" d="M224.63,-434.33C252.1,-423.34 289.78,-408.27 318.88,-396.63"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="320.41,-399.79 328.39,-392.82 317.81,-393.29 320.41,-399.79"/>
# </a>
# </g>
# </g>
# <!-- RiskAversion&#45;&gt;DrivHist -->
# <g id="edge10" class="edge">
# <title>RiskAversion-&gt;DrivHist</title>
# <g id="a_edge10"><a xlink:title="(3, 25) : ">
# <path fill="none" stroke="#4a4a4a" d="M161.4,-433.12C144.63,-423.09 122.82,-410.03 104.81,-399.26"/>
# <polygon fill="#4a4a4a"

# %%
acc = 0
domain = sorted(np.unique(y_train.to_numpy()))
for i in X_test.index :
    ie=gum.LazyPropagation(bn)
    ie.addTarget("Accident")
    instance = X_test.loc[i]
    for j in X_test.columns :
        ie.addEvidence(j,str(instance[j]))
    ie.makeInference()
    post = ie.posterior("Accident")
    #print(post)
    #print(y_test.loc[i])
    acc = acc + post[domain.index(y_test.loc[i])]
print(acc / len(X_test.index))
# Out:
# 0.92768882754402

# %%
bn.dag().dSeparation(bn.nodeset(["DrivHist"]),bn.nodeset(["CarValue"]),bn.nodeset(["DrivingSkill", "RiskAversion"]))
# Out:
# True

# %%
bn.nodeset(["OtherCarCost"])
# Out:
# <Swig Object of type 'gum::NodeSet *' at 0x7f6164831d50>

# %%
ie=gum.LazyPropagation(bn)
ie.makeInference()
ie.addEvidence("RiskAversion","Psychopath")
print(ie.posterior(bn.idFromName("Accident")))

# %%
ie=gum.LazyPropagation(bn)
#ie.makeInference()
ie.addEvidence("RiskAversion","Cautious")
ie.addTarget("Accident")
print(ie.posterior("Accident"))

# %%
l = np.unique(y_train.to_numpy())
print(sorted(l))

# %%
import bnlearn as bnl

# %%
model = bnl.structure_learning.fit(data)
model = bnl.parameter_learning.fit(model, data)

# %%
query = bnl.inference.fit(model, variables=['Accident'], evidence={'RiskAversion':"Psychopath"})

# %%
for i in range(0,4):
    print(ie.posterior(bn.idFromName("Accident"))[i])

# %%
le_X = preprocessing.OrdinalEncoder()
le_y = preprocessing.LabelEncoder()

X_train_en = le_X.fit_transform(X_train)
y_train_en = le_y.fit_transform(y_train)

# %%
clf = svm.SVC()
clf.fit(X_train_en, y_train_en)

# %%
clf.predict(le_X.transform(X_test))

# %%
# train an imputer 
imp = impute.SimpleImputer(missing_values=np.nan, strategy = "most_frequent")
#imp = impute.IterativeImputer(missing_values=np.nan, initial_strategy= "most_frequent")
imp.fit(X_train)

# %%
prueba = X_test.head(1).to_numpy()
prueba[0][10:26] = np.nan
imp.transform(prueba)

# %%
X_test.iloc[[1]]

# %%
X_observed = X.columns[0:20]
X_unobserved = [x for x in X if x not in X_observed]

# %%
def powerset(iterable):
    s = list(iterable)
    tmp = list(chain.from_iterable(combinations(s, r) for r in range(len(s)+1)))
    return tmp

# %%
S = powerset(X_unobserved)
S.pop(0)

# %%
S[10][1]

# %%
def omega(variable, data) :
    return list(data[variable].unique())

# %%
omega("Age",X)

# %%
# OPCIONES PARA PREDICT
# Estimar con los datos la clase más probable
# Estimar con los datos la missing data y utilizar el algoritmo
clf.predict(le_X.transform(X_test.head(1).to_numpy()))

# %%
prueba = X_test.head(1).to_numpy()

# %%
prueba[0][10:26] = np.nan

#prueba.iloc[0,20:26] = np.nan

# %% [raw]
# prueba

# %%
clf.predict(le_X.transform(X_test.head(1)))

# %%
X_observed

# %%
def reduce_dataset(instance, X,y) :
    columns = X.columns
    for i,value in enumerate(instance) :
        if isinstance(value, str) or not math.isnan(value) :
            X = X[X[columns[i]] == value]
            X = X.drop(columns[i], axis=1)
    y = y[[j for j in y.index if j in X.index]]
    return X,y

# %%
X['Age'] == "Adult"

# %%
X_test.head(1).to_numpy()

# %%
reduced = reduce_dataset(prueba[0], X)

# %%
bn.names()

# %%
bn.dag().dSeparation(bn.nodeset(["DrivHist"]),bn.nodeset(["CarValue"]),bn.nodeset(["DrivingSkill", "RiskAversion"]))
bn_pr = prune_network(bn, ["DrivingSkill", "RiskAversion"], ["DrivHist"])
#bn_pr.names()
# Out:
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor found.
# swig/python detected a memory leak of type 'gum::NodeSet *', no destructor fou

# %%
def prune_network(bn, ev_vars, hyp_vars) :
    #IMPORTANT: Hard copy of the bn
    bn_pr = gum.BayesNet(bn)
    # Find supplementary nodes of a network
    supp_vars = []
    for i in bn_pr.names() :
        if not i in ev_vars and not i in hyp_vars :
            supp_vars.append(i)
    # Delete from the network the nodes that are conditionally independent from the hypothesis variables (target) given the evidence
    for i in supp_vars :
        if bn_pr.dag().dSeparation(bn_pr.nodeset([i]),bn_pr.nodeset(hyp_vars),bn_pr.nodeset(ev_vars)):
            bn_pr.erase(i)
    return bn_pr

def predict_wrapper(instance, hyp_vars) :
    ie=gum.LazyPropagation(bn)
    ie.addTarget(hyp_vars)
    for i,value in enumerate(instance) :
        if isinstance(value, str) or not math.isnan(value) :
            ie.addEvidence(columns[i], )
            #ie.
            unobserved_vars.append(columns[i])
    

def omega(variables, data) :
    domains = []
    for variable in variables :
        domains.append(sorted(data[variable].unique()))
    return [p for p in product(*domains)]
    

# True if R is relevant/MAP-dependent
# False if R is irrelevant/MAP-independent
def map_independence(instances, set_R, data, bn, hyp_vars) : 
    #Type checking
    if isinstance(instances, pd.core.frame.DataFrame) :
        instances = instances.to_numpy()
    #Array for each instance
    out_array = []
    # For each instance:
    for instance in instances :
        # Check which are the missing variables
        columns = data.columns
        unobserved_vars = []
        for i,value in enumerate(instance) :
            if not isinstance(value, str) and math.isnan(value) :
                unobserved_vars.append(columns[i])
        # Check if R in unobserved
        #print(unobserved_vars)
        for R in set_R :
            if R not in unobserved_vars :
                print("Error")
                return
        # Impute and predict the instance
        complete_instance = imp.transform([instance])
        y = clf.predict(le_X.transform(complete_instance))
        # Obtain domain of R
        omega_R = omega(set_R, data)
        # For each value assignment r in omega(R)
        out_array.append(False)
        for value_assignment_r in omega_R :
            # Fill in values
            instance_alt = instance.copy()
            for i,value in enumerate(value_assignment_r) :
                instance_alt[list(data.columns).index(set_R[i])] = value
            #print(instance)
            #print(instance_alt)
            # Imputar y predecir 
            complete_instance_alt = imp.transform([instance_alt])
            y_alt = clf.predict(le_X.transform(complete_instance_alt))
            # Comparar con prediccion de instance
            #print(y, " == ", y_alt)
            if y != y_alt :
                out_array.pop()
                out_array.append(True)
                break
    return out_array

# %%
np.nan == np.nan

# %%
out = check_r(prueba, X_train.columns[15:20], X_train)
out

# %%
for i in range(10,23) :
    print(list(range(i,i+3)),check_r(prueba, X_train.columns[i:i+3], X_train))

# %%
def check_every_r(instances, data) :
    #Type checking
    if isinstance(instances, pd.core.frame.DataFrame) :
        instances = instances.to_numpy()
    #Array for each instance
    out_array = []
    # For each instance:
    for instance in instances :
        # Check which are the missing variables
        columns = data.columns
        unobserved_vars = []
        for i,value in enumerate(instance) :
            if not isinstance(value, str) and math.isnan(value) :
                unobserved_vars.append(columns[i])
        S = powerset(unobserved_vars)
        S.pop(0)
        relevant_sets = []
        irrelevant_sets = []
        for i in S :
            if check_r([instance], list(i), data)[0] :
                relevant_sets.append(i)
            else :
                irrelevant_sets.append(i)
        return relevant_sets, irrelevant_sets

# %%
def check_every_r_prune(instances, data) :
    #Type checking
    if isinstance(instances, pd.core.frame.DataFrame) :
        instances = instances.to_numpy()
    #Array for each instance
    out_array = []
    # For each instance:
    for instance in instances :
        # Check which are the missing variables
        columns = data.columns
        unobserved_vars = []
        for i,value in enumerate(instance) :
            if not isinstance(value, str) and math.isnan(value) :
                unobserved_vars.append(columns[i])
        S = powerset(unobserved_vars)
        S.pop(0)
        # Divide by length
        S_split = []
        size = 0
        for i in S :
            if len(i) != size:
                size = size + 1
                S_split.append([])
            S_split[-1].append(i)
        relevant_sets = []
        irrelevant_sets = []
        for i in range(0,len(S_split)) :
            for j in S_split[i] :
                # If relevant
                if check_r([instance], list(j), data)[0] :
                    relevant_sets.append(j)
                    # Apply prune
                    for k in range(i+1,len(S_split)) :
                        tmp = []
                        for l in S_split[k] :
                            if set(j).issubset(set(l)) :
                                relevant_sets.append(l)
                            else :
                                tmp.append(l)
                        S_split[k] = tmp
                # If irrelevant
                else :
                    irrelevant_sets.append(j)
        return relevant_sets, irrelevant_sets

# %%
prueba = X_test.head(1).to_numpy()
prueba[0][0:10] = np.nan
t0 = time.time()
relevant_sets, irrelevant_sets = check_every_r(prueba, X_train)
tf = time.time()
print("Brute force: ",tf-t0)

# %%
t0 = time.time()
relevant_sets_p, irrelevant_sets_p = check_every_r_prune(prueba, X_train)
tf = time.time()
print("Prune: ",tf-t0)

# %%
print(relevant_sets == relevant_sets_p)
print(irrelevant_sets == irrelevant_sets_p)

# %%
irrelevant_sets

# %%
# TODO FSS
X_red, y_red = reduce_dataset(prueba[0], X_train, y_train)

# %%
X_red

# %%
y_red

# %%
#sel = feature_selection.GenericUnivariateSelect()
oe = preprocessing.OrdinalEncoder()
sel = feature_selection.RFECV(svm.SVC(kernel="linear"))
sel.fit_transform(oe.fit_transform(X_red),y_red)
sel.support_

# %%
print(X_red.columns[sel.support_ == False])

# %%
feature_selection.mutual_info_classif(oe.fit_transform(X_red),y_red)

# %%
sel = feature_selection.GenericUnivariateSelect(feature_selection.chi2)
X_new = sel.fit_transform(oe.fit_transform(X_red),y_red)
sel.get_support()

# %%
import sklearn
from pgmpy import estimators, models, inference

# %%
# Structure learning
scoring_method = estimators.K2Score(data=app)
est = estimators.HillClimbSearch(data=app)
estimated_model = est.estimate(
    scoring_method=scoring_method, max_iter=int(1e2*5)
)
#sklearn.metrics.get_f1_score(estimated_model, model)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
# Parameter learning
example = models.BayesianNetwork(estimated_model)
example.fit(app)

# %%
from pgmpy.models import BayesianModel
import networkx as nx
import pylab as plt
pos = nx.nx_agraph.graphviz_layout(example)
nx.draw(example, pos=pos, with_labels=True)
plt.show()

# %%
acc = 0
domain = sorted(np.unique(y_train.to_numpy()))
for i in X_test.index :
    dictio = dict()
    instance = X_test.loc[i]
    for j in X_test.columns :
        dictio[j] = instance[j]
    inf = inference.VariableElimination(example)
    post = inf.query(['Accident'], evidence = dictio)
    print(post)
    #print(y_test.loc[i])
    acc = acc + post.values[domain.index(y_test.loc[i])]
print(acc / len(X_test.index))
# Out:
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.1186 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.8814 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0082 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9918 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0021 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9979 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0070 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9930 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0069 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9931 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9989 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0011 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9989 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0011 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.3664 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.6336 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.1398 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.8581 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0021 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0261 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0007 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9732 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0298 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0007 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9695 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9583 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0417 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0017 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9983 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9992 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0008 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.2856 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0115 |
# +--------------------+-----------------+
# | Accident(None)     |          0.7028 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0001 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0069 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9931 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0954 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9046 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0242 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.9758 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.2370 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.7630 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9989 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0011 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0013 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9987 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9990 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0010 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0070 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9930 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0131 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0005 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9864 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.1138 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.8862 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0460 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.9540 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0078 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9922 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0530 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.9470 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9578 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0422 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0016 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9984 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.1186 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.8814 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0079 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9921 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.1138 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.8862 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0242 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.9758 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0069 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9931 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0006 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9994 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.3696 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.6304 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0236 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.9764 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0263 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0007 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9730 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.1411 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.8568 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0021 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0079 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9921 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0501 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9499 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0069 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9931 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0078 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9922 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0074 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9926 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0634 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9366 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0634 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9366 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0070 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9930 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0083 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9917 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0261 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0007 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9732 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.1128 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.8872 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0070 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9930 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0272 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0007 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9720 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9989 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0011 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9993 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0007 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0064 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0002 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9934 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0070 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9930 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0628 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.9372 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0032 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9968 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9582 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0418 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0244 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.5995 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.3761 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.6272 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.3728 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0455 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.9545 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0460 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.9540 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0615 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.9385 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0461 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.9539 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0261 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0007 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9732 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0954 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9046 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0024 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9975 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0069 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9931 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.1152 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.8848 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.1186 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.8814 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0021 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9979 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0261 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0007 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9732 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.2389 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.7611 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0012 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9988 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.2053 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0082 |
# +--------------------+-----------------+
# | Accident(None)     |          0.7864 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0001 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.3368 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0137 |
# +--------------------+-----------------+
# | Accident(None)     |          0.6493 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0001 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0060 |
# ...
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.4151 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.5849 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9582 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0418 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0078 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9922 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0263 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0007 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9730 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9989 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0011 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.1186 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.8814 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.3368 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0137 |
# +--------------------+-----------------+
# | Accident(None)     |          0.6493 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0001 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0155 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.5722 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.4123 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.9885 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0115 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0058 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0001 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9941 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0074 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9926 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0055 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.9945 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0298 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0007 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9695 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.2856 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0115 |
# +--------------------+-----------------+
# | Accident(None)     |          0.7028 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0001 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.1431 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.8497 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0072 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0010 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9990 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.4532 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0192 |
# +--------------------+-----------------+
# | Accident(None)     |          0.5274 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0002 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.3696 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.6304 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0010 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9990 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0954 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9046 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0001 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9999 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9990 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0010 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          1.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0954 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9046 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.0026 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0000 |
# +--------------------+-----------------+
# | Accident(None)     |          0.9974 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# +--------------------+-----------------+
# | Accident           |   phi(Accident) |
# +====================+=================+
# | Accident(Mild)     |          0.9582 |
# +--------------------+-----------------+
# | Accident(Moderate) |          0.0418 |
# +--------------------+-----------------+
# | Accident(None)     |          0.0000 |
# +--------------------+-----------------+
# | Accident(Severe)   |          0.0000 |
# +--------------------+-----------------+
# 0.9279284684389891

# %%
type(example)

# %%
bm = pgmpy.models.BayesianModel(example)

# %%
post
# Out:
# <DiscreteFactor representing phi(Accident:4) at 0x7f2f0938df70>

# %%
post.values
# Out:
# array([6.47770312e-05, 0.00000000e+00, 9.99935223e-01, 0.00000000e+00])
